# %%
import pandas as pd

file = 'C:\\Users\\Bob\Documents\\Repos\\sql-crash-course\\Labs\\Lab 4\\data\\customers_by_total_spent.csv'

# %%
customers = pd.read_csv(file)

# %%
customers.head()
# Out:
#   first_name last_name                            email  \
# 0      Aaron     Selby   aaron.selby@sakilacustomer.org
# 1       Adam     Gooch    adam.gooch@sakilacustomer.org
# 2     Adrian     Clary  adrian.clary@sakilacustomer.org
# 3      Agnes    Bishop  agnes.bishop@sakilacustomer.org
# 4       Alan      Kahn     alan.kahn@sakilacustomer.org
#
#                                 address  address2        city  postal_code  \
# 0  1519 Santiago de los Caballeros Loop       NaN  Mwene-Ditu        22025
# 1                       230 Urawa Drive       NaN       Adoni         2738
# 2                      1986 Sivas Place       NaN       Udine        95775
# 3                   866 Shivapuri Manor       NaN     Sambhal        22474
# 4                     753 Ilorin Avenue       NaN    Emeishan         3656
#
#                                  country customer_is_active  \
# 0  Congo, The Democratic Republic of the                Yes
# ...
